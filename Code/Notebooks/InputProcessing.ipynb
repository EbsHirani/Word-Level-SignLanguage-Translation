# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
dicti = {}

# %%
li = ["handposeGreetingsBothHands.json", "handposePronounssBothHands.json", "handposeDays_and_TimeBothHands.json", "handposePeopleBothHands.json"]
for i in li:
  dicti.update(json.load(open(f"/content/drive/MyDrive/MP sign language/Results/{i}", 'r')))

# %% [markdown]
# For Variable seqlen

# %%
cls_list = []
for i in dicti:
  cls = " ".join(i.split('/')[0].split()[1:])
  cls_list.append(cls)

# %%
cls_li = []
for i in set(cls_list):
  if list(cls_list).count(i) >= 0 :
    cls_li.append(i)
print(len(cls_li))
# Out:
# 56

# %%
import random
import numpy as np
X = []
Y = []
seq_len = 109
count = 0
for i in dicti:
  cls = i.split('/')[0].split()[1]
  if cls in cls_li:
    li_set = []
    points = dicti[i]
    for img in points:
      li = []
      # print(img)
      # print(points[img])
  
      for hand in points[img]:
        for p in hand:
          # li.append(p['X'])
          # li.append(p['Y'])
          # li.append(p['Z'])
          li.append([p['X'], p['Y'], p["Z"]])
      if len(li)!= 42:
        li = li[:42]
      li_set.append(li)
      

    if len(li_set):
      for _ in range(20):
        
        p = []
        for j in li_set:
          # print(j)
          if random.random() > 0.3:
            p.append(np.array(j))
        # print(len(p), i)
        # for j in range(len(p), seq_len):
        #   p.append(np.array([[1,1,1]]*42))
        # print(len(p))
        p = np.array(p)
        p = np.expand_dims(np.array(p), axis = 0)
        if len(p.shape) == 4:
        # print(p.shape)
          rng = p.max(axis = 2).reshape(p.shape[0], p.shape[1], -1, p.shape[3]) - p.min(axis = 2).reshape(p.shape[0], p.shape[1], -1, p.shape[3])
          mini = p.min(axis = 2).reshape(p.shape[0], p.shape[1], -1, p.shape[3])
          p = (p - mini)/rng
          p[np.isnan(p)] = 0
          # print(p[0][0])
          p = p.reshape(p.shape[1], -1)
          if p.shape[-1] == 126:
            X.append(p)
            Y.append(cls)
        # else:
        #   for st in p[0]:
        #     if st.shape != (42,3):
        #       print(st.shape)
print(count)
print(np.array(X).shape)
# Out:
# 0
# (18540,)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:58: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
X = np.array(X)
Y = np.array(Y)
# X = X[ind]
# Y = Y[ind]
print(X.shape, Y.shape)
# Out:
# (18540,) (18540,)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """Entry point for launching an IPython kernel.

# %%
import pickle
with open('/content/drive/MyDrive/MP sign language/Results/X_var.pkl','wb') as f:
  pickle.dump(X, f)
with open('/content/drive/MyDrive/MP sign language/Results/Y_var.pkl','wb') as f:
  pickle.dump(Y, f)

# %%
print(len(set(Y)))
# Out:
# 49

# %% [markdown]
# For same seqlen

# %%
len(dicti)
# Out:
# 934

# %%
seq_len = 0
for i in dicti:
  cls = " ".join(i.split('/')[0].split()[1:])
  li_set = []
  points = dicti[i]
  seq_len = max(seq_len, len(points))
print(seq_len)
# Out:
# 109

# %%
import numpy as np
X = []
Y = []
for i in dicti:
  cls = i.split('/')[0].split()[1]
  # li_set = []
  points = dicti[i]
  for img in points:
    li = []
    # print(img)
    # print(points[img])
    for hand in points[img]:
      for p in hand:
        # li.append(p['X'])
        # li.append(p['Y'])
        # li.append(p['Z'])
        li.append([p['X'], p['Y'], p["Z"]])
    # X.append(li)
    # Y.append(cls)
  

  # print(i)
  # if len(li_set):
  #   for i in range(len(li_set), seq_len):
  #     li_set.append([[1,1,1]]*42)
  #   # print(len(li_set[0]))
  #   print(len(li_set))
  #   X.append(li_set)
  #   Y.append(cls)

# %%
X
# Out:
# []

# %%
X = np.array(X)
Y = np.array(Y)

# %%
print(X.shape, Y.shape)
# Out:
# (0,) (0,)

# %%
import pickle
with open('/content/drive/MyDrive/MP sign language/Results/X_w.pkl','wb') as f:
  pickle.dump(X, f)
with open('/content/drive/MyDrive/MP sign language/Results/Y_w.pkl','wb') as f:
  pickle.dump(Y, f)

# %% [markdown]
# For sequential

# %%
cls_list = []
for i in dicti:
  cls = " ".join(i.split('/')[0].split()[1:])
  cls_list.append(cls)

# %%
cls_li = []
for i in set(cls_list):
  if list(cls_list).count(i) >= 0 :
    cls_li.append(i)
print(len(cls_li))
# Out:
# 56

# %%
cls_li
# Out:
# ['Year',
#  'Grandmother',
#  'Neighbour',
#  'Good Morning',
#  'Sunday',
#  'we',
#  'Father',
#  'Girl',
#  'Thank you',
#  'Wednesday',
#  'Grandfather',
#  'I',
#  'Tuesday',
#  'Monday',
#  'Child',
#  'Thursday',
#  'he',
#  'Woman',
#  'Good evening',
#  'Sister',
#  'Tomorrow',
#  'Good night',
#  'Month',
#  'Queen',
#  'Crowd',
#  'Adult',
#  'you (plural)',
#  'Saturday',
#  'Pleased',
#  'she',
#  'Family',
#  'Today',
#  'you',
#  'Daughter',
#  'Man',
#  'President',
#  'Boy',
#  'Son',
#  'Mother',
#  'Wife',
#  'Yesterday',
#  'Player',
#  'Friday',
#  'it',
#  'Alright',
#  'Brother',
#  'they',
#  'Husband',
#  'Good afternoon',
#  'Hello',
#  'Friend',
#  'How are you',
#  'Week',
#  'Parent',
#  'King',
#  'Baby']

# %%
import numpy as np
import random
X = []
Y = []
seq_len = 50
for i in dicti:
  cls = i.split('/')[0].split()[1]
  if cls in cls_li:
    li_set = []
    points = dicti[i]
    for img in points:
      li = []
      # print(img)
      # print(points[img])
      for hand in points[img]:
        for p in hand:
          # li.append(p['X'])
          # li.append(p['Y'])
          # li.append(p['Z'])
          li.append([p['X'], p['Y'], p["Z"]])
      if len(li)!= 42:
        li = li[:42]
      li_set.append(li)

    if len(li_set):
      for _ in range(20):
        p = []
        for j in li_set:
          # print(j)
          if random.random() > 0.3:
            p.append(np.array(j))

            if len(p) == seq_len:
              break
        # print(len(p), i)
        for j in range(len(p), seq_len):
          p.append(np.array([[1,1,1]]*42))
        # print(len(p))
        p = np.array(p)
        if p.shape == (seq_len, 42, 3):
          X.append(p)
          Y.append(cls)
        
        

  # print(i)
  # if len(li_set):
  #   for i in range(len(li_set), seq_len):
  #     li_set.append([[1,1,1]]*42)
  #   # print(len(li_set[0]))
  #   print(len(li_set))
  #   X.append(li_set)
  #   Y.append(cls)

# %%
# Out:
# 3

# %%
# cls_li = []
# for i in set(Y):
#   if list(Y).count(i) >= 410 :
#     cls_li.append(i)
# # print(len(cls_li))

# %%
len(X)
# Out:
# 18540

# %%
# ind = [i in cls_li for i in Y]
# print(ind)
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, T
# ...

# %%
X = np.array(X)
Y = np.array(Y)
# X = X[ind]
# Y = Y[ind]
print(X.shape, Y.shape)
# Out:
# (18540, 50, 42, 3) (18540,)

# %%
rng = X.max(axis = 2).reshape(X.shape[0], X.shape[1], -1, X.shape[3]) - X.min(axis = 2).reshape(X.shape[0], X.shape[1], -1, X.shape[3])
mini = X.min(axis = 2).reshape(X.shape[0], X.shape[1], -1, X.shape[3])
X = (X - mini)/rng
X[np.isnan(X)] = 0
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
X[0][0].shape
# Out:
# (42, 3)

# %%
import pickle
with open('/content/drive/MyDrive/MP sign language/Results/X.pkl','wb') as f:
  pickle.dump(X, f)
with open('/content/drive/MyDrive/MP sign language/Results/Y.pkl','wb') as f:
  pickle.dump(Y, f)
